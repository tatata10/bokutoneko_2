# %%
print "adada"
# Out:
#   Cell In[1], line 1
#     print "adada"
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
print(naoao)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(naoao)
#
# NameError: name 'naoao' is not defined

# %%
print("kakak")
# Out:
# kakak
